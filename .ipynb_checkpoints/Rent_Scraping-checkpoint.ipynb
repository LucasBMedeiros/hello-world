# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Importando bibliotecas:
import pandas as pd
from urllib.request import Request, urlopen, urlretrieve
from urllib.error import URLError, HTTPError
from bs4 import BeautifulSoup

# Declarando variável cards:
cards = []

## Obtendo o HTML e o total de páginas:
url = 'https://rn.olx.com.br/rio-grande-do-norte/natal/imoveis/aluguel/apartamentos?o=1'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
try:
    req = Request(url, headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)

# Criando o objeto soup:
soup = BeautifulSoup(html, 'html.parser')

# Número de páginas: *dependendo do site pode ser atomatizado ou coletado manualmente como nesse caso
pages = int(29)

## Iterando por todas as páginas do site:
for i in range(pages):
    ## Obtendo o HTML
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
    req = Request('https://rn.olx.com.br/rio-grande-do-norte/natal/imoveis/aluguel/apartamentos?o=' + str(i + 1), headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    # Obtendo as TAGs de interesse
    anuncios = soup.find('div', {"id": "column-main-content"}).findAll('div', class_="fnmrjs-2 jiSLYe")
    # Coletando as informações dos CARDS
    for anuncio in anuncios:
        card = {}
        
        # Nome do anúncio
        nome = anuncio.find("h2").getText()
        card['NOME'] = nome
        
        # Valor
        span_valor = anuncio.find("span", class_="sc-ifAKCX eoKYee")
        valor = span_valor.get_text() if span_valor else ''
        card["VALOR"] = valor

        # Detalhes
        span_detalhe = anuncio.find("span", class_="sc-1j5op1p-0 lnqdIU sc-ifAKCX eLPYJb")
        detalhe = span_detalhe.get_text().split('|') if span_detalhe else ''
        card['DETALHES'] = detalhe

        # Endereço
        span_endereco = anuncio.find('span', class_="sc-7l84qu-1 ciykCV sc-ifAKCX dpURtf")
        endereco = span_endereco.getText().split(', ')[1] if span_endereco else ''
        card['ENDEREÇO'] = endereco

        # Adicionando resultado a lista cards
        cards.append(card)

# Criando um DataFrame com os resultados
df = pd.DataFrame(cards)
df
# Out:
#                                                    NOME     VALOR  \
# 0     Torres Amintas Barros Residence, Lagoa Nova - ...  R$ 1.450
# 1     Imperdível! Lindo Apto, 3º andar | Sombra | Re...    R$ 900
# 2     Alugo apartamento com 160me em Lagoa Nova e va...  R$ 4.000
# 3     Apartamento Mobiliado em Ponta Negra (internet...  R$ 1.300
# 4             Apartamento no Corais Enseada de P. Negra  R$ 1.750
# ...                                                 ...       ...
# 1443        A oportunidade em você morar em Lagoas Nova  R$ 1.300
# 1444                                        Apartamento  R$ 2.000
# 1445  Loft alto padrão em Cond.Fechado em Morro Bran...    R$ 750
# 1446  Excelente apartamento com 3 quartos em Candelaria  R$ 3.150
# 1447  Alugo Kitnets Espaçosos e Aconchegantes em Nov...    R$ 450
#
#                                                DETALHES  \
# 0                        [2 quartos ,  56m² ,  2 vagas]
# 1               [3 quartos ,  86m² ,  Condomínio: R$ 1]
# 2     [4 quartos ,  160m² ,  Condomínio: R$ 0 ,  4 v...
# 3                          [1 quarto ,  35m² ,  1 vaga]
# 4     [3 quartos ,  96m² ,  Condomínio: R$ 530 ,  2 ...
# ...                                                 ...
# 1443                              [2 quartos ,  1 vaga]
# 1444                      [2 quartos ,  56m² ,  1 vaga]
# 1445                     [1 quarto ,  Condomínio: R$ 0]
# 1446                     [3 quartos ,  98m² ,  2 vagas]
# 1447                                         [1 quarto]
#
#                      ENDEREÇO
# 0     Nossa Senhora de Nazaré
# 1                    Neópolis
# 2             Dix-Sept Rosado
# 3                 Ponta Negra
# 4                 Ponta Negra
# ...                       ...
# 1443              Ponta Negra
# 1444              Ponta Negra
# 1445          Nova Descoberta
# 1446               Candelária
# 1447              Capim Macio
#
# [1448 rows x 4 columns]

# %%
# Importando bibliotecas:
import pandas as pd
from urllib.request import Request, urlopen, urlretrieve
from urllib.error import URLError, HTTPError
from bs4 import BeautifulSoup

# Declarando variável cards:
cards = []

## Obtendo o HTML e o total de páginas:
url = 'https://rn.olx.com.br/rio-grande-do-norte/outras-cidades/parnamirim/imoveis/aluguel?q=parnamirim&sf=1'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
try:
    req = Request(url, headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)

# Criando o objeto soup:
soup = BeautifulSoup(html, 'html.parser')

# Número de páginas: *dependendo do site pode ser atomatizado ou coletado manualmente como nesse caso
pages = int(10)

## Iterando por todas as páginas do site:
for i in range(pages):
    ## Obtendo o HTML
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
    req = Request('https://rn.olx.com.br/rio-grande-do-norte/outras-cidades/parnamirim/imoveis/aluguel?q=parnamirim&sf=' + str(i + 1), headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    # Obtendo as TAGs de interesse
    anuncios = soup.find('div', {"id": "column-main-content"}).findAll('div', class_="fnmrjs-2 jiSLYe")
    # Coletando as informações dos CARDS
    for anuncio in anuncios:
        card = {}
        
        # Nome do anúncio
        nome = anuncio.find("h2").getText()
        card['NOME'] = nome
        
        # Valor
        span_valor = anuncio.find("span", class_="sc-ifAKCX eoKYee")
        valor = span_valor.get_text() if span_valor else ''
        card["VALOR"] = valor

        # Detalhes
        span_detalhe = anuncio.find("span", class_="sc-1j5op1p-0 lnqdIU sc-ifAKCX eLPYJb")
        detalhe = span_detalhe.get_text().split('|') if span_detalhe else ''
        card['DETALHES'] = detalhe

        # Endereço
        span_endereco = anuncio.find('span', class_="sc-7l84qu-1 ciykCV sc-ifAKCX dpURtf")
        endereco = span_endereco.getText().split(', ')[1] if span_endereco else ''
        card['ENDEREÇO'] = endereco

        # Adicionando resultado a lista cards
        cards.append(card)

# Criando um DataFrame com os resultados
df_parn = pd.DataFrame(cards)
df_parn
# Out:
#                                                   NOME     VALOR  \
# 0                      Aluga-se kit net em Parnamirim     R$ 300
# 1    Cond. Rio Branco:Apto 2/4 com suíte entre a Mª...  R$ 1.000
# 2    Apartamento no Condomínio Ideal Vila Nova, loc...    R$ 900
# 3                               Kitnet Nova Parnamirim    R$ 550
# 4                                             Montreal    R$ 700
# ..                                                 ...       ...
# 485               Casa para alugar no Jardim Aeroporto    R$ 500
# 486  Alugo Casa Mobiliada de 2/4 sem fiador com gar...    R$ 600
# 487                           Casa em nova Parnamirim     R$ 900
# 488  Apartamento com 2 dormitórios para alugar, 551...    R$ 650
# 489  Aluguel - Apartamento em Cidade Verde - Campos...  R$ 1.900
#
#                                               DETALHES            ENDEREÇO
# 0                                           [1 quarto]         Santos Reis
# 1                        [2 quartos ,  60m² ,  1 vaga]     Nova Parnamirim
# 2    [3 quartos ,  56m² ,  Condomínio: R$ 0 ,  1 vaga]  Parque das Árvores
# 3     [1 quarto ,  30m² ,  Condomínio: R$ 0 ,  1 vaga]     Nova Parnamirim
# 4     [1 quarto ,  45m² ,  Condomínio: R$ 1 ,  1 vaga]     Nova Parnamirim
# ..                                                 ...                 ...
# 485                                        [3 quartos]               Emaús
# 486                      [2 quartos ,  65m² ,  1 vaga]               Emaús
# 487                             [3 quartos ,  2 vagas]     Nova Parnamirim
# 488  [2 quartos ,  5512m² ,  Condomínio: R$ 210 ,  ...     Rosa dos Ventos
# 489                                [3 quartos ,  78m²]     Nova Parnamirim
#
# [490 rows x 4 columns]

# %%
<span color="dark" title="Parnamirim, Pium (Distrito Litoral)" class="sc-7l84qu-1 ciykCV sc-ifAKCX dpURtf" font-weight="400">Parnamirim, Pium (Distrito Litoral)</span>

# %% [markdown]
# # Concat DataFrames

# %%
frames = [df,df_parn]
df1 = pd.concat(frames, axis=0, ignore_index = True).reset_index()

# %%
df1
# Out:
#       index                                               NOME     VALOR  \
# 0         0  Torres Amintas Barros Residence, Lagoa Nova - ...  R$ 1.450
# 1         1  Imperdível! Lindo Apto, 3º andar | Sombra | Re...    R$ 900
# 2         2  Alugo apartamento com 160me em Lagoa Nova e va...  R$ 4.000
# 3         3  Apartamento Mobiliado em Ponta Negra (internet...  R$ 1.300
# 4         4          Apartamento no Corais Enseada de P. Negra  R$ 1.750
# ...     ...                                                ...       ...
# 1933   1933               Casa para alugar no Jardim Aeroporto    R$ 500
# 1934   1934  Alugo Casa Mobiliada de 2/4 sem fiador com gar...    R$ 600
# 1935   1935                           Casa em nova Parnamirim     R$ 900
# 1936   1936  Apartamento com 2 dormitórios para alugar, 551...    R$ 650
# 1937   1937  Aluguel - Apartamento em Cidade Verde - Campos...  R$ 1.900
#
#                                                DETALHES  \
# 0                        [2 quartos ,  56m² ,  2 vagas]
# 1               [3 quartos ,  86m² ,  Condomínio: R$ 1]
# 2     [4 quartos ,  160m² ,  Condomínio: R$ 0 ,  4 v...
# 3                          [1 quarto ,  35m² ,  1 vaga]
# 4     [3 quartos ,  96m² ,  Condomínio: R$ 530 ,  2 ...
# ...                                                 ...
# 1933                                        [3 quartos]
# 1934                      [2 quartos ,  65m² ,  1 vaga]
# 1935                             [3 quartos ,  2 vagas]
# 1936  [2 quartos ,  5512m² ,  Condomínio: R$ 210 ,  ...
# 1937                                [3 quartos ,  78m²]
#
#                      ENDEREÇO
# 0     Nossa Senhora de Nazaré
# 1                    Neópolis
# 2             Dix-Sept Rosado
# 3                 Ponta Negra
# 4                 Ponta Negra
# ...                       ...
# 1933                    Emaús
# 1934                    Emaús
# 1935          Nova Parnamirim
# 1936          Rosa dos Ventos
# 1937          Nova Parnamirim
#
# [1938 rows x 5 columns]

# %%
df1 = df1[['NOME', 'VALOR', 'DETALHES', 'ENDEREÇO']]
df1
# Out:
#                                                    NOME     VALOR  \
# 0     Torres Amintas Barros Residence, Lagoa Nova - ...  R$ 1.450
# 1     Imperdível! Lindo Apto, 3º andar | Sombra | Re...    R$ 900
# 2     Alugo apartamento com 160me em Lagoa Nova e va...  R$ 4.000
# 3     Apartamento Mobiliado em Ponta Negra (internet...  R$ 1.300
# 4             Apartamento no Corais Enseada de P. Negra  R$ 1.750
# ...                                                 ...       ...
# 1933               Casa para alugar no Jardim Aeroporto    R$ 500
# 1934  Alugo Casa Mobiliada de 2/4 sem fiador com gar...    R$ 600
# 1935                           Casa em nova Parnamirim     R$ 900
# 1936  Apartamento com 2 dormitórios para alugar, 551...    R$ 650
# 1937  Aluguel - Apartamento em Cidade Verde - Campos...  R$ 1.900
#
#                                                DETALHES  \
# 0                        [2 quartos ,  56m² ,  2 vagas]
# 1               [3 quartos ,  86m² ,  Condomínio: R$ 1]
# 2     [4 quartos ,  160m² ,  Condomínio: R$ 0 ,  4 v...
# 3                          [1 quarto ,  35m² ,  1 vaga]
# 4     [3 quartos ,  96m² ,  Condomínio: R$ 530 ,  2 ...
# ...                                                 ...
# 1933                                        [3 quartos]
# 1934                      [2 quartos ,  65m² ,  1 vaga]
# 1935                             [3 quartos ,  2 vagas]
# 1936  [2 quartos ,  5512m² ,  Condomínio: R$ 210 ,  ...
# 1937                                [3 quartos ,  78m²]
#
#                      ENDEREÇO
# 0     Nossa Senhora de Nazaré
# 1                    Neópolis
# 2             Dix-Sept Rosado
# 3                 Ponta Negra
# 4                 Ponta Negra
# ...                       ...
# 1933                    Emaús
# 1934                    Emaús
# 1935          Nova Parnamirim
# 1936          Rosa dos Ventos
# 1937          Nova Parnamirim
#
# [1938 rows x 4 columns]

# %%
df1.to_csv('df1_unclean.csv')

# %%
df1.to_excel('df1_unclean.xlsx')
